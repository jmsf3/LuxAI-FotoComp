# %% [markdown]
# # ***Exercícios - Pandas***
# ---

# %% [markdown]
# ## **Dados de Teste**
# ---

# %%
import os

if not os.path.isdir('ml-book-exemplos'):
    # !git clone https://github.com/infoslack/ml-book-exemplos.git

# %% [markdown]
# ## **Bibliotecas**
# ---

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **01**
# ---

# %%
# Load CSV file
df = pd.read_csv('/content/ml-book-exemplos/data/venda-de-carros-formatado.csv')

# Show the first 5 rows of the DataFrame
print(df.head())
# Out:
#   Fabricante       Cor  Quilometragem  Portas     Preco
# 0     Toyota    Branco         150043       4   24000.0
# 1      Honda  Vermelho          87899       4   25000.0
# 2     Toyota      Azul          32549       3   27000.0
# 3        BMW     Preto          11179       5  122000.0
# 4     Nissan    Branco         213095       4   13500.0

# %% [markdown]
# ## **02**
# ---

# %%
# Get the name of all of the columns in the DataFrame
print(f'The names of the columns are {list(df.columns)}')
# Out:
# The names of the columns are ['Fabricante', 'Cor', 'Quilometragem', 'Portas', 'Preco']

# %% [markdown]
# ## **03**
# ---

# %%
# Show general statistical information of the DataFrame
print(df.describe())
# Out:
#        Quilometragem     Portas         Preco
# count      10.000000  10.000000      10.00000
# mean    78601.400000   4.000000   31645.00000
# std     61983.471735   0.471405   32153.87008
# min     11179.000000   3.000000   13500.00000
# 25%     35836.250000   4.000000   18050.00000
# 50%     57369.000000   4.000000   24500.00000
# 75%     96384.500000   4.000000   26812.50000
# max    213095.000000   5.000000  122000.00000

# %% [markdown]
# ## **04**
# ---

# %%
# Verify and remove rows that contain missing values (NaN)
df.dropna()
print(df)
# Out:
#   Fabricante       Cor  Quilometragem  Portas     Preco
# 0     Toyota    Branco         150043       4   24000.0
# 1      Honda  Vermelho          87899       4   25000.0
# 2     Toyota      Azul          32549       3   27000.0
# 3        BMW     Preto          11179       5  122000.0
# 4     Nissan    Branco         213095       4   13500.0
# 5     Toyota     Verde          99213       4   14500.0
# 6      Honda      Azul          45698       4   17500.0
# 7      Honda      Azul          54738       4   27000.0
# 8     Toyota    Branco          60000       4   26250.0
# 9     Nissan    Branco          31600       4   19700.0

# %% [markdown]
# ## **05**
# ---

# %%
# Check if every column has an appropiate data type
for col in df:
    print(df[col])
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Fabricante, dtype: object
# 0      Branco
# 1    Vermelho
# 2        Azul
# 3       Preto
# 4      Branco
# 5       Verde
# 6        Azul
# 7        Azul
# 8      Branco
# 9      Branco
# Name: Cor, dtype: object
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Quilometragem, dtype: int64
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Portas, dtype: int64
# 0     24000.0
# 1     25000.0
# 2     27000.0
# 3    122000.0
# 4     13500.0
# 5     14500.0
# 6     17500.0
# 7     27000.0
# 8     26250.0
# 9     19700.0
# Name: Preco, dtype: float64

# %% [markdown]
# ## **06**
# ---

# %%
# Select the cars that contain exactly 4 doors
print(df[df['Portas'] == 4])
# Out:
#   Fabricante       Cor  Quilometragem  Portas    Preco
# 0     Toyota    Branco         150043       4  24000.0
# 1      Honda  Vermelho          87899       4  25000.0
# 4     Nissan    Branco         213095       4  13500.0
# 5     Toyota     Verde          99213       4  14500.0
# 6      Honda      Azul          45698       4  17500.0
# 7      Honda      Azul          54738       4  27000.0
# 8     Toyota    Branco          60000       4  26250.0
# 9     Nissan    Branco          31600       4  19700.0

# %% [markdown]
# ## **07**
# ---

# %%
# Print the size of the DataFrame
rows, cols = df.shape

print(f'This DataFrame contais {rows} rows and {cols} columns')
# Out:
# This DataFrame contais 10 rows and 5 columns

# %% [markdown]
# ## **08**
# ---

# %%
# Get the second item of the DataFrame
print(df.iloc[1])
# Out:
# Fabricante          Honda
# Cor              Vermelho
# Quilometragem       87899
# Portas                  4
# Preco             25000.0
# Name: 1, dtype: object

# %% [markdown]
# ## **09**
# ---

# %%
# Get the mean of the mileage values
print(df['Quilometragem'].mean())
# Out:
# 78601.4
